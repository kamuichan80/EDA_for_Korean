# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
detraindata = pd.read_csv('./v0.80/y_train_de__v0.80.csv')
devaldata = pd.read_csv('./v0.80/y_val_de__v0.80.csv')
detestdata = pd.read_csv('./v0.80/y_test_de__v0.80.csv')
extraindata = pd.read_csv('./v0.80/y_train_ex__v0.80.csv')
exvaldata = pd.read_csv('./v0.80/y_val_ex__v0.80.csv')
extestdata = pd.read_csv('./v0.80/y_test_ex__v0.80.csv')
detraindata
devaldata
detestdata
extraindata
exvaldata
extestdata
# Out:
#        Unnamed: 0  LABEL
# 0          244584     17
# 1          125013     17
# 2          198389     17
# 3          134647     20
# 4          109747      3
# ...           ...    ...
# 11724      125087     20
# 11725      104181     17
# 11726      198232     17
# 11727      326239     26
# 11728       81861     17
#
# [11729 rows x 2 columns]

# %%
sns.barplot(x=detraindata['LABEL'].value_counts(normalize=True).sort_index().index, y=detraindata['LABEL'].value_counts(normalize=True).sort_index().values)
#devaldata['LABEL'].value_counts(normalize=True).sort_index()
#detestdata['LABEL'].value_counts(normalize=True).sort_index()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=extraindata['LABEL'].value_counts(normalize=True).sort_index().index, y=extraindata['LABEL'].value_counts(normalize=True).sort_index().values)
#exvaldata['LABEL'].value_counts(normalize=True).sort_index()
#extestdata['LABEL'].value_counts(normalize=True).sort_index()
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x=detraindata['LABEL'])
# Out:
# <AxesSubplot:xlabel='LABEL', ylabel='count'>

# %%
sns.countplot(x=extraindata['LABEL'])
# Out:
# <AxesSubplot:xlabel='LABEL', ylabel='count'>
